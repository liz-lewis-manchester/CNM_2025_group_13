# %% [markdown]
# **Task 2: Storage of matrix**
#
# This notebook checks the use of the function created in Task 2 in src/solver.py

# %%
L = 20.0
Delta_x = 0.2
Delta_t = 10.0
U = 0.1

N_x = int(L / Delta_x) + 1

# %%
import os
if not os.path.exists('/content/CNM_2025_group_13'):
    # !git clone https://github.com/liz-lewis-manchester/CNM_2025_group_13.git

import sys
sys.path.append('/content/CNM_2025_group_13')

from src.solver import storing_matrix
import numpy as np

# %%
A, B = storing_matrix(N_x, Delta_t, Delta_x, U)

print('A:')
print(A)
print(' ')
print('B:')
print(B)
# Out:
# A:
# [0.6 0.6 0.6 0.6 0.6 0.6 0.6 0.6 0.6 0.6 0.6 0.6 0.6 0.6 0.6 0.6 0.6 0.6
#  0.6 0.6 0.6 0.6 0.6 0.6 0.6 0.6 0.6 0.6 0.6 0.6 0.6 0.6 0.6 0.6 0.6 0.6
#  0.6 0.6 0.6 0.6 0.6 0.6 0.6 0.6 0.6 0.6 0.6 0.6 0.6 0.6 0.6 0.6 0.6 0.6
#  0.6 0.6 0.6 0.6 0.6 0.6 0.6 0.6 0.6 0.6 0.6 0.6 0.6 0.6 0.6 0.6 0.6 0.6
#  0.6 0.6 0.6 0.6 0.6 0.6 0.6 0.6 0.6 0.6 0.6 0.6 0.6 0.6 0.6 0.6 0.6 0.6
#  0.6 0.6 0.6 0.6 0.6 0.6 0.6 0.6 0.6 0.6]
#
# B:
# [-0.5 -0.5 -0.5 -0.5 -0.5 -0.5 -0.5 -0.5 -0.5 -0.5 -0.5 -0.5 -0.5 -0.5
#  -0.5 -0.5 -0.5 -0.5 -0.5 -0.5 -0.5 -0.5 -0.5 -0.5 -0.5 -0.5 -0.5 -0.5
#  -0.5 -0.5 -0.5 -0.5 -0.5 -0.5 -0.5 -0.5 -0.5 -0.5 -0.5 -0.5 -0.5 -0.5
#  -0.5 -0.5 -0.5 -0.5 -0.5 -0.5 -0.5 -0.5 -0.5 -0.5 -0.5 -0.5 -0.5 -0.5
#  -0.5 -0.5 -0.5 -0.5 -0.5 -0.5 -0.5 -0.5 -0.5 -0.5 -0.5 -0.5 -0.5 -0.5
#  -0.5 -0.5 -0.5 -0.5 -0.5 -0.5 -0.5 -0.5 -0.5 -0.5 -0.5 -0.5 -0.5 -0.5
#  -0.5 -0.5 -0.5 -0.5 -0.5 -0.5 -0.5 -0.5 -0.5 -0.5 -0.5 -0.5 -0.5 -0.5
#  -0.5 -0.5]

# %%
# Test 1: Correct length
assert len(A) == N_x - 1
assert len(B) == N_x - 1

# Test 2: Coefficients are constant for uniform velocity
assert np.allclose(A, A[0])
assert np.allclose(B, B[0])

print("Task 2 tests passed.")
# Out:
# Task 2 tests passed.

# %% [markdown]
# **Conclusion:**
# The vectors A and B are constant as expected for an uniform velocity field. This check that the code is running properly.
